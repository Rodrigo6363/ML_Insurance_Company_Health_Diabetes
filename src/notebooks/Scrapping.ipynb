# %% [markdown]
# # IMPORTS

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import os

# %% [markdown]
# # TRAIN DATA

# %% [markdown]
# ### Demographic data

# %%
file_mapping = {
    "2021": ["DEMO_L.xpt"],
    "2017": ["P_DEMO.xpt", "DEMO_J.xpt"],
    "2015": ["DEMO_I.xpt"],
    "2013": ["DEMO_H.xpt"],
    "2011": ["DEMO_G.xpt"],
    "2009": ["DEMO_F.xpt"],
    "2007": ["DEMO_E.xpt"],
    "2005": ["DEMO_D.xpt"],
    "2003": ["DEMO_C.xpt"],
    "2001": ["DEMO_B.xpt"],
    "1999": ["DEMO.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/DEMO/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/DEMO_L.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_L.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DEMO.xpt
# Archivo guardado: ../data/raw_data/DEMO/P_DEMO.xpt
# Convertido a CSV: ../data/raw_data/DEMO/P_DEMO_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/DEMO_J.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_J.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/DEMO_I.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_I.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/DEMO_H.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_H.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/DEMO_G.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_G.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/DEMO_F.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_F.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/DEMO_E.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_E.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/DEMO_D.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_D.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/DEMO_C.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_C.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/DEMO_B.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO_B.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/DEMO.xpt
# Archivo guardado: ../data/raw_data/DEMO/DEMO.xpt
# Convertido a CSV: ../data/raw_data/DEMO/DEMO_1999.csv

# %% [markdown]
# ### HDL

# %%
# Diccionario con nombres de archivo específicos por año
file_mapping = {
    "2021": ["HDL_L.xpt"],
    "2017": ["P_HDL.xpt", "HDL_J.xpt"],
    "2015": ["HDL_I.xpt"],
    "2013": ["HDL_H.xpt"],
    "2011": ["HDL_G.xpt"],
    "2009": ["HDL_F.xpt"],
    "2007": ["HDL_E.xpt"],
    "2005": ["HDL_D.xpt"],
    "2003": ["L13_C.xpt"],
    "2001": ["L13_B.xpt"],
    "1999": ["LAB13.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/HDL/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/HDL_L.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_L.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HDL.xpt
# Archivo guardado: ../data/raw_data/HDL/P_HDL.xpt
# Convertido a CSV: ../data/raw_data/HDL/P_HDL_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/HDL_J.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_J.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/HDL_I.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_I.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/HDL_H.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_H.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/HDL_G.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_G.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/HDL_F.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_F.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/HDL_E.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_E.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/HDL_D.xpt
# Archivo guardado: ../data/raw_data/HDL/HDL_D.xpt
# Convertido a CSV: ../data/raw_data/HDL/HDL_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/L13_C.xpt
# Archivo guardado: ../data/raw_data/HDL/L13_C.xpt
# Convertido a CSV: ../data/raw_data/HDL/L13_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/L13_B.xpt
# Archivo guardado: ../data/raw_data/HDL/L13_B.xpt
# Convertido a CSV: ../data/raw_data/HDL/L13_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/LAB13.xpt
# Archivo guardado: ../data/raw_data/HDL/LAB13.xpt
# Convertido a CSV: ../data/raw_data/HDL/LAB13_1999.csv

# %%
# Diccionario con nombres de archivo específicos por año (sin 1999, 2001, 2003)

file_mapping = {
    "2021": ["TCHOL_L.xpt"],
    "2017": ["P_TCHOL.xpt", "TCHOL_J.xpt"],
    "2015": ["TCHOL_I.xpt"],
    "2013": ["TCHOL_H.xpt"],
    "2011": ["TCHOL_G.xpt"],
    "2009": ["TCHOL_F.xpt"],
    "2007": ["TCHOL_E.xpt"],
    "2005": ["TCHOL_D.xpt"],
}


# Carpeta de salida
output_folder = "../data/raw_data/chol_total/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/TCHOL_L.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_L.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_TCHOL.xpt
# Archivo guardado: ../data/raw_data/chol_total/P_TCHOL.xpt
# Convertido a CSV: ../data/raw_data/chol_total/P_TCHOL_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/TCHOL_J.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_J.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/TCHOL_I.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_I.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/TCHOL_H.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_H.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/TCHOL_G.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_G.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/TCHOL_F.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_F.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/TCHOL_E.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_E.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/TCHOL_D.xpt
# Archivo guardado: ../data/raw_data/chol_total/TCHOL_D.xpt
# Convertido a CSV: ../data/raw_data/chol_total/TCHOL_D_2005.csv

# %% [markdown]
# ### Glycohemoglobin (GHB)

# %%
# Diccionario con nombres de archivo específicos por año


file_mapping = {
    "2021": ["GHB_L.xpt"],
    "2017": ["P_GHB.xpt", "GHB_J.xpt"],
    "2015": ["GHB_I.xpt"],
    "2013": ["GHB_H.xpt"],
    "2011": ["GHB_G.xpt"],
    "2009": ["GHB_F.xpt"],
    "2007": ["GHB_E.xpt"],
    "2005": ["GHB_D.xpt"],
    "2003": ["L10_C.xpt"],
    "2001": ["L10_B.xpt"],
    "1999": ["LAB10.xpt"]
}
# Carpeta de salida
output_folder = "../data/raw_data/GHB/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/GHB_L.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_L.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_GHB.xpt
# Archivo guardado: ../data/raw_data/GHB/P_GHB.xpt
# Convertido a CSV: ../data/raw_data/GHB/P_GHB_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/GHB_J.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_J.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/GHB_I.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_I.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/GHB_H.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_H.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/GHB_G.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_G.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/GHB_F.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_F.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/GHB_E.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_E.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/GHB_D.xpt
# Archivo guardado: ../data/raw_data/GHB/GHB_D.xpt
# Convertido a CSV: ../data/raw_data/GHB/GHB_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/L10_C.xpt
# Archivo guardado: ../data/raw_data/GHB/L10_C.xpt
# Convertido a CSV: ../data/raw_data/GHB/L10_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/L10_B.xpt
# Archivo guardado: ../data/raw_data/GHB/L10_B.xpt
# Convertido a CSV: ../data/raw_data/GHB/L10_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/LAB10.xpt
# Archivo guardado: ../data/raw_data/GHB/LAB10.xpt
# Convertido a CSV: ../data/raw_data/GHB/LAB10_1999.csv

# %% [markdown]
# ### Insulin

# %%
# Diccionario con nombres de archivo específicos por año
file_mapping = {
    "2021": ["INS_L.xpt"],
    "2017": ["P_INS.xpt", "INS_J.xpt"],
    "2015": ["INS_I.xpt"],
    "2013": ["INS_H.xpt"],
    "2011": ["INS_G.xpt"],
    "2009": ["INS_F.xpt"],
    "2007": ["INS_E.xpt"],
    "2005": ["INS_D.xpt"],
    "2003": ["L10AM_C.xpt"],
    "2001": ["L10_2_B.xpt"],
    "1999": ["LAB10AM.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/INS/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}


# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/INS_L.xpt
# Archivo guardado: ../data/raw_data/INS/INS_L.xpt
# Convertido a CSV: ../data/raw_data/INS/INS_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_INS.xpt
# Archivo guardado: ../data/raw_data/INS/P_INS.xpt
# Convertido a CSV: ../data/raw_data/INS/P_INS_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/INS_J.xpt
# Archivo guardado: ../data/raw_data/INS/INS_J.xpt
# Convertido a CSV: ../data/raw_data/INS/INS_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/INS_I.xpt
# Archivo guardado: ../data/raw_data/INS/INS_I.xpt
# Convertido a CSV: ../data/raw_data/INS/INS_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/INS_H.xpt
# Archivo guardado: ../data/raw_data/INS/INS_H.xpt
# Convertido a CSV: ../data/raw_data/INS/INS_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/INS_G.xpt
# ❌ Error 404 al descargar https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/INS_G.xpt
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/INS_F.xpt
# ❌ Error 404 al descargar https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/INS_F.xpt
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/INS_E.xpt
# ❌ Error 404 al descargar https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/INS_E.xpt
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/INS_D.xpt
# ❌ Error 404 al descargar https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/INS_D.xpt
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/L10AM_C.xpt
# Archivo guardado: ../data/raw_data/INS/L10AM_C.xpt
# Convertido a CSV: ../data/raw_data/INS/L10AM_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/L10_2_B.xpt
# Archivo guardado: ../data/raw_data/INS/L10_2_B.xpt
# Convertido a CSV: ../data/raw_data/INS/L10_2_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/LAB10AM.xpt
# Archivo guardado: ../data/raw_data/INS/LAB10AM.xpt
# Convertido a CSV: ../data/raw_data/INS/LAB10AM_1999.csv

# %% [markdown]
# ### Fasting Glucose and more Insulin data

# %%
# Diccionario con nombres de archivo específicos por año (sin 1999, 2001, 2003)
file_mapping = {
    "2017": ["GLU_J.xpt"],
    "2015": ["GLU_I.xpt"],
    "2013": ["GLU_H.xpt"],
    "2011": ["GLU_G.xpt"],
    "2009": ["GLU_F.xpt"],
    "2007": ["GLU_E.xpt"],
    "2005": ["GLU_D.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/GLU/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/GLU_J.xpt
# Archivo guardado: ../data/raw_data/GLU/GLU_J.xpt
# Convertido a CSV: ../data/raw_data/GLU/GLU_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/GLU_I.xpt
# Archivo guardado: ../data/raw_data/GLU/GLU_I.xpt
# Convertido a CSV: ../data/raw_data/GLU/GLU_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/GLU_H.xpt
# Archivo guardado: ../data/raw_data/GLU/GLU_H.xpt
# Convertido a CSV: ../data/raw_data/GLU/GLU_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/GLU_G.xpt
# Archivo guardado: ../data/raw_data/GLU/GLU_G.xpt
# Convertido a CSV: ../data/raw_data/GLU/GLU_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/GLU_F.xpt
# Archivo guardado: ../data/raw_data/GLU/GLU_F.xpt
# Convertido a CSV: ../data/raw_data/GLU/GLU_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/GLU_E.xpt
# Archivo guardado: ../data/raw_data/GLU/GLU_E.xpt
# Convertido a CSV: ../data/raw_data/GLU/GLU_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/GLU_D.xpt
# Archivo guardado: ../data/raw_data/GLU/GLU_D.xpt
# Convertido a CSV: ../data/raw_data/GLU/GLU_D_2005.csv

# %% [markdown]
# ### Standard Biochemistry Profile

# %%
# Diccionario con nombres de archivo específicos por año
file_mapping = {
    "2021": ["BIOPRO_L.xpt"],
    "2017": ["P_BIOPRO.xpt", "BIOPRO_J.xpt"],
    "2015": ["BIOPRO_I.xpt"],
    "2013": ["BIOPRO_H.xpt"],
    "2011": ["BIOPRO_G.xpt"],
    "2009": ["BIOPRO_F.xpt"],
    "2007": ["BIOPRO_E.xpt"],
    "2005": ["BIOPRO_D.xpt"],
    "2003": ["L40_C.xpt"],
    "2001": ["L40_B.xpt"],
    "1999": ["LAB18.xpt"]
}


# Carpeta de salida
output_folder = "../data/raw_data/BIOPRO/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/BIOPRO_L.xpt
# ❌ Error 404 al descargar https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/BIOPRO_L.xpt
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_BIOPRO.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/P_BIOPRO.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/P_BIOPRO_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/BIOPRO_J.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/BIOPRO_J.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/BIOPRO_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/BIOPRO_I.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/BIOPRO_I.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/BIOPRO_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/BIOPRO_H.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/BIOPRO_H.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/BIOPRO_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/BIOPRO_G.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/BIOPRO_G.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/BIOPRO_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/BIOPRO_F.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/BIOPRO_F.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/BIOPRO_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/BIOPRO_E.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/BIOPRO_E.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/BIOPRO_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/BIOPRO_D.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/BIOPRO_D.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/BIOPRO_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/L40_C.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/L40_C.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/L40_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/L40_B.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/L40_B.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/L40_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/LAB18.xpt
# Archivo guardado: ../data/raw_data/BIOPRO/LAB18.xpt
# Convertido a CSV: ../data/raw_data/BIOPRO/LAB18_1999.csv

# %% [markdown]
# ### Weight and Heigth data

# %%
# Diccionario con nombres de archivo específicos por año

file_mapping = {
    "2021": ["WHQ_L.xpt"],
    "2017": ["P_WHQ.xpt", "WHQ_J.xpt"],
    "2015": ["WHQ_I.xpt"],
    "2013": ["WHQ_H.xpt"],
    "2011": ["WHQ_G.xpt"],
    "2009": ["WHQ_F.xpt"],
    "2007": ["WHQ_E.xpt"],
    "2005": ["WHQ_D.xpt"],
    "2003": ["WHQ_C.xpt"],
    "2001": ["WHQ_B.xpt"],
    "1999": ["WHQ.xpt"]
}


# Carpeta de salida
output_folder = "../data/raw_data/weight/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/WHQ_L.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_L.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_WHQ.xpt
# Archivo guardado: ../data/raw_data/weight/P_WHQ.xpt
# Convertido a CSV: ../data/raw_data/weight/P_WHQ_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/WHQ_J.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_J.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/WHQ_I.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_I.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/WHQ_H.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_H.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/WHQ_G.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_G.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/WHQ_F.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_F.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/WHQ_E.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_E.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/WHQ_D.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_D.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/WHQ_C.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_C.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/WHQ_B.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ_B.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/WHQ.xpt
# Archivo guardado: ../data/raw_data/weight/WHQ.xpt
# Convertido a CSV: ../data/raw_data/weight/WHQ_1999.csv

# %% [markdown]
# ### Diabetes train data

# %%
# Diccionario con nombres de archivo específicos por año

file_mapping = {
    "2021": ["DIQ_L.xpt"],
    "2017": ["P_DIQ.xpt", "DIQ_J.xpt"],
    "2015": ["DIQ_I.xpt"],
    "2013": ["DIQ_H.xpt"],
    "2011": ["DIQ_G.xpt"],
    "2009": ["DIQ_F.xpt"],
    "2007": ["DIQ_E.xpt"],
    "2005": ["DIQ_D.xpt"],
    "2003": ["DIQ_C.xpt"],
    "2001": ["DIQ_B.xpt"],
    "1999": ["DIQ.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/diabetes/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/DIQ_L.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_L.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DIQ.xpt
# Archivo guardado: ../data/raw_data/diabetes/P_DIQ.xpt
# Convertido a CSV: ../data/raw_data/diabetes/P_DIQ_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/DIQ_J.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_J.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/DIQ_I.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_I.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/DIQ_H.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_H.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/DIQ_G.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_G.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/DIQ_F.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_F.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/DIQ_E.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_E.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/DIQ_D.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_D.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/DIQ_C.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_C.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/DIQ_B.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ_B.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/DIQ.xpt
# Archivo guardado: ../data/raw_data/diabetes/DIQ.xpt
# Convertido a CSV: ../data/raw_data/diabetes/DIQ_1999.csv

# %% [markdown]
# ### Blood pressure

# %%
file_mapping = {
    "2021": ["BPQ_L.xpt"],
    "2017": ["P_BPQ.xpt", "BPQ_J.xpt"],
    "2015": ["BPQ_I.xpt"],
    "2013": ["BPQ_H.xpt"],
    "2011": ["BPQ_G.xpt"],
    "2009": ["BPQ_F.xpt"],
    "2007": ["BPQ_E.xpt"],
    "2005": ["BPQ_D.xpt"],
    "2003": ["BPQ_C.xpt"],
    "2001": ["BPQ_B.xpt"],
    "1999": ["BPQ.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/BPQ/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/BPQ_L.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_L.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_BPQ.xpt
# Archivo guardado: ../data/raw_data/BPQ/P_BPQ.xpt
# Convertido a CSV: ../data/raw_data/BPQ/P_BPQ_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/BPQ_J.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_J.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/BPQ_I.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_I.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/BPQ_H.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_H.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/BPQ_G.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_G.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/BPQ_F.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_F.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/BPQ_E.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_E.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/BPQ_D.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_D.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/BPQ_C.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_C.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/BPQ_B.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ_B.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/BPQ.xpt
# Archivo guardado: ../data/raw_data/BPQ/BPQ.xpt
# Convertido a CSV: ../data/raw_data/BPQ/BPQ_1999.csv

# %% [markdown]
# ### Smoking use

# %%
file_mapping = {
    "2021": ["SMQ_L.xpt"],
    "2017": ["P_SMQ.xpt", "SMQ_J.xpt"],
    "2015": ["SMQ_I.xpt"],
    "2013": ["SMQ_H.xpt"],
    "2011": ["SMQ_G.xpt"],
    "2009": ["SMQ_F.xpt"],
    "2007": ["SMQ_E.xpt"],
    "2005": ["SMQ_D.xpt"],
    "2003": ["SMQ_C.xpt"],
    "2001": ["SMQ_B.xpt"],
    "1999": ["SMQ.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/SMQ/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/SMQ_L.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_L.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SMQ.xpt
# Archivo guardado: ../data/raw_data/SMQ/P_SMQ.xpt
# Convertido a CSV: ../data/raw_data/SMQ/P_SMQ_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/SMQ_J.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_J.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/SMQ_I.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_I.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/SMQ_H.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_H.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/SMQ_G.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_G.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/SMQ_F.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_F.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/SMQ_E.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_E.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/SMQ_D.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_D.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/SMQ_C.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_C.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/SMQ_B.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ_B.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/SMQ.xpt
# Archivo guardado: ../data/raw_data/SMQ/SMQ.xpt
# Convertido a CSV: ../data/raw_data/SMQ/SMQ_1999.csv

# %% [markdown]
# ### Alcohol use

# %%
file_mapping = {
    "2021": ["ALQ_L.xpt"],
    "2017": ["P_ALQ.xpt", "ALQ_J.xpt"],
    "2015": ["ALQ_I.xpt"],
    "2013": ["ALQ_H.xpt"],
    "2011": ["ALQ_G.xpt"],
    "2009": ["ALQ_F.xpt"],
    "2007": ["ALQ_E.xpt"],
    "2005": ["ALQ_D.xpt"],
    "2003": ["ALQ_C.xpt"],
    "2001": ["ALQ_B.xpt"],
    "1999": ["ALQ.xpt"]
}

# Carpeta de salida
output_folder = "../data/raw_data/ALQ/"
os.makedirs(output_folder, exist_ok=True)

# Headers para la solicitud
headers = {"User-Agent": "Mozilla/5.0"}

# Bucle por año y archivos
for year, file_list in file_mapping.items():
    # Asegura que file_list sea una lista
    if isinstance(file_list, str):
        file_list = [file_list]
    
    for filename_xpt in file_list:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{filename_xpt}"

        print(f"Descargando: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            xpt_path = os.path.join(output_folder, filename_xpt)
            with open(xpt_path, "wb") as f:
                f.write(response.content)
            print(f"Archivo guardado: {xpt_path}")

            # Convertir a CSV
            try:
                df = pd.read_sas(xpt_path, format="xport")
                csv_name = filename_xpt.replace(".xpt", f"_{year}.csv")
                csv_path = os.path.join(output_folder, csv_name)
                df.to_csv(csv_path, index=False)
                os.remove(xpt_path)
                print(f"Convertido a CSV: {csv_path}")
            except Exception as e:
                print(f"Error al convertir {filename_xpt}: {e}")
        else:
            print(f"❌ Error {response.status_code} al descargar {url}")
# Out:
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/ALQ_L.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_L.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_L_2021.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_ALQ.xpt
# Archivo guardado: ../data/raw_data/ALQ/P_ALQ.xpt
# Convertido a CSV: ../data/raw_data/ALQ/P_ALQ_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/ALQ_J.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_J.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_J_2017.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/ALQ_I.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_I.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_I_2015.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2013/DataFiles/ALQ_H.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_H.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_H_2013.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2011/DataFiles/ALQ_G.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_G.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_G_2011.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2009/DataFiles/ALQ_F.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_F.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_F_2009.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2007/DataFiles/ALQ_E.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_E.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_E_2007.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2005/DataFiles/ALQ_D.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_D.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_D_2005.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2003/DataFiles/ALQ_C.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_C.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_C_2003.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2001/DataFiles/ALQ_B.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ_B.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_B_2001.csv
# Descargando: https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/ALQ.xpt
# Archivo guardado: ../data/raw_data/ALQ/ALQ.xpt
# Convertido a CSV: ../data/raw_data/ALQ/ALQ_1999.csv
